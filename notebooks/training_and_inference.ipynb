# %% [markdown]
# # Code for training and testing of Mask3D on .las forest plots
#
# Since the data is not yet currently available, I've kept the outputs of the code to demonstrate that it does actually work!

# %% [markdown]
# # Installs: (this takes about 1 hour)
#
# This complicated install setup is necessary to get things running on Colab

# %%
# %%capture

# !git clone "https://github.com/ruarimh/Mask3D"
# %cd /content/Mask3D

# !pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu116
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-1.12.1+cu116.html

# !pip install ninja==1.10.2.3
# !pip install pytorch-lightning==1.7.2
# !pip install fire==0.4.0
# !pip install imageio==2.21.1
# !pip install tqdm==4.64.0
# !pip install wandb==0.13.2
# !pip install python-dotenv==0.20.0
# !pip install pyviz3d==0.2.28
# !pip install scipy==1.9.0
# !pip install plyfile==0.7.4
# !pip install scikit-learn==1.1.2
# !pip install trimesh==3.14.0
# !pip install loguru==0.6.0
# !pip install albumentations==1.2.1
# !pip install volumentations==0.1.8
# !pip install laspy

# !pip install antlr4-python3-runtime==4.8
# !pip install black==21.4b2
# !pip install omegaconf==2.0.6 hydra-core==1.0.5 --no-deps
# !pip install 'git+https://github.com/facebookresearch/detectron2.git@710e7795d0eeadf9def0e7ef957eea13532e34cf' --no-deps

# !pip install git+https://github.com/NVIDIA/MinkowskiEngine.git -v

# !pip install -r requirements.txt

# %cd third_party/pointnet2
# !python setup.py install

# %cd /content/Mask3D

"""
# !pip install torch torchvision --extra-index-url https://download.pytorch.org/whl/cu116
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-1.12.1+cu116.html
"""

# !pip install omegaconf==2.0.6 hydra-core==1.0.5 --no-deps
# !cp "/content/Mask3D/third_party/pytorch/types.py" "/usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/types.py"

# %% [markdown]
# # Get .las data for all the plots

# %%
# import your Google Drive, assuming your data is stored there

import os
from google.colab import drive
drive.mount('/content/drive')
drive_folder = '/content/drive/MyDrive'
# Out:
# Mounted at /content/drive

# %%
# !mkdir /content/Mask3D/data/
# !mkdir /content/Mask3D/data/las/
# !mkdir /content/Mask3D/data/las/train
# !mkdir /content/Mask3D/data/las/validation
# !mkdir /content/Mask3D/data/las/test

# copy the FORinstance_dataset onto Colab
# !cp -R /content/drive/MyDrive/MRes/Data/FORinstance_dataset/ /content/Mask3D/data/

# %% [markdown]
# # Training Mask3D

# %%
# split the data into the train/validation/test subsets
import random
import pandas as pd
import shutil

data_location = "/content/Mask3D/data/FORinstance_dataset/"
train_location = "/content/Mask3D/data/las/train/"
validation_location = "/content/Mask3D/data/las/validation/"
test_location = "/content/Mask3D/data/las/test/"

validation_plots = ["plot59_annotated.las", "plot26_annotated.las",
                    "plot21_annotated.las", "plot8_annotated.las",
                    "plot20_annotated.las", "plot57_annotated.las",
                    "plot12_annotated.las"]

data_split_metadata = pd.read_csv(data_location + "data_split_metadata.csv")
data_split_metadata = data_split_metadata[data_split_metadata["folder"] == "NIBIO2"]

for path in data_split_metadata["path"]:
    if data_split_metadata.loc[data_split_metadata["path"] == path]["split"].item() == "train":
        shutil.copyfile(data_location + path, train_location + path.replace("NIBIO2/", ""))
    else:
        shutil.copyfile(data_location + path, test_location + path.replace("NIBIO2/", ""))

train_files = os.listdir(train_location)

for train_file in train_files:
    if train_file in validation_plots:
        shutil.copyfile(train_location + train_file, validation_location + train_file)
        os.remove(train_location + train_file)

# %%
# make sure you run the code from within the Mask3D directory
# %cd /content/Mask3D/

# %%
# run the preprocessing script on the .las files

# !python -m datasets.preprocessing.las_preprocessing preprocess \
--data_dir="/content/Mask3D/data/las" \
--save_dir="/content/Mask3D/data/processed/las" \
--sample_proportion=1 \
--use_rgb=True \
--subplot_size=500.0
# Out:
# 2023-06-29 18:20:57.613 | INFO     | datasets.preprocessing.base_preprocessing:preprocess:51 - Tasks for train: 28
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    3.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   11.1s finished
# 2023-06-29 18:21:08.765 | INFO     | datasets.preprocessing.base_preprocessing:preprocess:51 - Tasks for validation: 7
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    7.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    9.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   11.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   12.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   12.2s finished
# 2023-06-29 18:21:21.007 | INFO     | datasets.preprocessing.base_preprocessing:preprocess:51 - Tasks for test: 15
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    3.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    3.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    5.2s finished

# %%
# log in to weights and biases to track experiment -- not required
# !wandb login

# %% [markdown]
# Below is the main training script. The output logs are there to show that it actually works

# %%
# %%shell
# export OMP_NUM_THREADS=3
#
# CURR_DBSCAN=14.0
# CURR_TOPK=10
# CURR_QUERY=160
# CURR_SIZE=250
#
# EXPERIMENT_NAME="all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb"
# SAVE_DIRECTORY="/content/drive/MyDrive/MRes/saved/"
#
# # TRAIN
# python main_instance_segmentation.py \
# general.experiment_name=${EXPERIMENT_NAME} \
# general.project_name="las" \
# data/datasets=las \
# general.num_targets=2 \
# data.num_labels=2 \
# data.voxel_size=8.0 \
# data.num_workers=0 \
# data.cache_data=true \
# data.cropping_v1=false \
# data.cropping=false \
# data.batch_size=8 \
# data.test_batch_size=1 \
# general.reps_per_epoch=5 \
# model.num_queries=${CURR_QUERY} \
# general.use_dbscan=false \
# general.on_crops=true \
# model.config.backbone._target_=models.Res16UNet18B \
# data.crop_length=${CURR_SIZE} \
# data.subplot_size=500.0 \
# general.eval_inner_core=-1 \
# general.save_visualizations=false \
# general.save_dir="${SAVE_DIRECTORY}${EXPERIMENT_NAME}" \
# trainer.check_val_every_n_epoch=10 \
# trainer.max_epochs=500
# Out:
# /content/Mask3D/trainer/trainer.py:825: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(False, 'class not known!')
# 2023-06-27 12:32:41.705425: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/seed.py:55: UserWarning: No seed found, seed set to 2773444861
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 2773444861
# EXPERIMENT ALREADY EXIST
# {'_target_': 'pytorch_lightning.loggers.WandbLogger', 'project': '${general.project_name}', 'name': '${general.experiment_name}', 'save_dir': '${general.save_dir}', 'entity': 'ram212', 'resume': 'allow', 'id': '${general.experiment_name}'}
# wandb: Currently logged in as: ram212. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.2
# wandb: Run data is saved locally in /content/drive/MyDrive/MRes/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb/wandb/run-20230627_123244-all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Resuming run all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb
# wandb: ⭐️ View project at https://wandb.ai/ram212/las
# wandb: 🚀 View run at https://wandb.ai/ram212/las/runs/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb
# [2023-06-27 12:32:47,504][__main__][INFO] - {'general_train_mode': True, 'general_task': 'instance_segmentation', 'general_seed': None, 'general_checkpoint': None, 'general_backbone_checkpoint': None, 'general_freeze_backbone': False, 'general_linear_probing_backbone': False, 'general_train_on_segments': False, 'general_eval_on_segments': False, 'general_filter_out_instances': False, 'general_save_visualizations': False, 'general_visualization_point_size': 20, 'general_decoder_id': -1, 'general_export': False, 'general_use_dbscan': False, 'general_ignore_class_threshold': 100, 'general_project_name': 'las', 'general_workspace': 'jonasschult', 'general_experiment_name': 'all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb', 'general_num_targets': 2, 'general_add_instance': True, 'general_dbscan_eps': 0.95, 'general_dbscan_min_points': 1, 'general_export_threshold': 0.0001, 'general_reps_per_epoch': 5, 'general_on_crops': True, 'general_scores_threshold': 0.0, 'general_iou_threshold': 1.0, 'general_area': 5, 'general_eval_inner_core': -1, 'general_topk_per_image': 100, 'general_ignore_mask_idx': [], 'general_max_batch_size': 99999999, 'general_save_dir': '/content/drive/MyDrive/MRes/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb', 'general_gpus': 1, 'data_train_mode': 'train', 'data_validation_mode': 'validation', 'data_test_mode': 'validation', 'data_ignore_label': 255, 'data_add_raw_coordinates': True, 'data_add_colors': True, 'data_add_normals': False, 'data_in_channels': 3, 'data_num_labels': 2, 'data_add_instance': True, 'data_task': 'instance_segmentation', 'data_pin_memory': False, 'data_num_workers': 0, 'data_batch_size': 8, 'data_test_batch_size': 1, 'data_cache_data': True, 'data_voxel_size': 8.0, 'data_reps_per_epoch': 5, 'data_cropping': False, 'data_cropping_args_min_points': 30000, 'data_cropping_args_aspect': 0.8, 'data_cropping_args_min_crop': 0.5, 'data_cropping_args_max_crop': 1.0, 'data_crop_min_size': 20000, 'data_crop_length': 250, 'data_subplot_size': 500.0, 'data_cropping_v1': False, 'data_train_dataloader__target_': 'torch.utils.data.DataLoader', 'data_train_dataloader_shuffle': True, 'data_train_dataloader_pin_memory': False, 'data_train_dataloader_num_workers': 0, 'data_train_dataloader_batch_size': 8, 'data_validation_dataloader__target_': 'torch.utils.data.DataLoader', 'data_validation_dataloader_shuffle': False, 'data_validation_dataloader_pin_memory': False, 'data_validation_dataloader_num_workers': 1, 'data_validation_dataloader_batch_size': 1, 'data_test_dataloader__target_': 'torch.utils.data.DataLoader', 'data_test_dataloader_shuffle': False, 'data_test_dataloader_pin_memory': False, 'data_test_dataloader_num_workers': 1, 'data_test_dataloader_batch_size': 1, 'data_train_dataset__target_': 'datasets.semseg.SemanticSegmentationDataset', 'data_train_dataset_dataset_name': 'las', 'data_train_dataset_data_dir': 'data/processed/las', 'data_train_dataset_image_augmentations_path': 'conf/augmentation/albumentations_aug.yaml', 'data_train_dataset_volume_augmentations_path': 'conf/augmentation/volumentations_aug.yaml', 'data_train_dataset_label_db_filepath': 'data/processed/las/label_database.yaml', 'data_train_dataset_color_mean_std': 'data/processed/las/color_mean_std.yaml', 'data_train_dataset_data_percent': 1.0, 'data_train_dataset_mode': 'train', 'data_train_dataset_ignore_label': 255, 'data_train_dataset_num_labels': 2, 'data_train_dataset_add_raw_coordinates': True, 'data_train_dataset_add_colors': True, 'data_train_dataset_add_normals': False, 'data_train_dataset_add_instance': True, 'data_train_dataset_cache_data': True, 'data_train_dataset_instance_oversampling': 0.0, 'data_train_dataset_place_around_existing': False, 'data_train_dataset_point_per_cut': 0, 'data_train_dataset_max_cut_region': 0, 'data_train_dataset_flip_in_center': False, 'data_train_dataset_noise_rate': 0, 'data_train_dataset_resample_points': 0, 'data_train_dataset_cropping': F ...
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:446: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:52: LightningDeprecationWarning: Setting `Trainer(resume_from_checkpoint=)` is deprecated in v1.5 and will be removed in v1.7. Please pass `Trainer.fit(ckpt_path=)` directly instead.
#   rank_zero_deprecation(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:57: LightningDeprecationWarning: Setting `Trainer(weights_save_path=)` has been deprecated in v1.6 and will be removed in v1.8. Please pass ``dirpath`` directly to the `ModelCheckpoint` callback
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py:733: LightningDeprecationWarning: `trainer.resume_from_checkpoint` is deprecated in v1.5 and will be removed in v2.0. Specify the fit checkpoint path with `trainer.fit(ckpt_path=)` instead.
#   ckpt_path = ckpt_path or self.resume_from_checkpoint
# /content/Mask3D/datasets/semseg.py:594: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(f)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:616: UserWarning: Checkpoint directory /content/drive/MyDrive/MRes/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# Restoring states from the checkpoint path at /content/drive/MyDrive/MRes/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb/last-epoch.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type         | Params
# -------------------------------------------
# 0 | model     | Mask3D       | 19.0 M
# 1 | criterion | SetCriterion | 0
# -------------------------------------------
# 19.0 M    Trainable params
# 0         Non-trainable params
# 19.0 M    Total params
# 75.810    Total estimated model params size (MB)
# Restored all states from the checkpoint file at /content/drive/MyDrive/MRes/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb/last-epoch.ckpt
# Sanity Checking DataLoader 0: 100% 2/2 [00:16<00:00,  8.01s/it]Computing AP for class:  1
# 1 0.12415132291912655
# Computing AP for class:  1
# 1 0.20345063022592116
# evaluating 2 scans...
# scans processed: 2
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.103          0.170          0.247
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.103          0.170          0.247
#
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py:1894: PossibleUserWarning: The number of training batches (18) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 380: 100% 18/18 [01:35<00:00,  5.30s/it, loss=113, v_num=orgb]Checkpoint created
# Epoch 381: 100% 18/18 [01:29<00:00,  4.99s/it, loss=112, v_num=orgb]Checkpoint created
# Epoch 382: 100% 18/18 [01:32<00:00,  5.12s/it, loss=112, v_num=orgb]Checkpoint created
# Epoch 383: 100% 18/18 [01:26<00:00,  4.81s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 384: 100% 18/18 [01:28<00:00,  4.94s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 385: 100% 18/18 [01:31<00:00,  5.07s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 386: 100% 18/18 [01:28<00:00,  4.89s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 387: 100% 18/18 [01:29<00:00,  4.95s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 388: 100% 18/18 [01:28<00:00,  4.94s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 389:   0% 0/25 [00:00<?, ?it/s, loss=110, v_num=orgb]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 389:  80% 20/25 [01:37<00:24,  4.88s/it, loss=110, v_num=orgb]
# Epoch 389: 100% 25/25 [01:58<00:00,  4.75s/it, loss=110, v_num=orgb]Computing AP for class:  1
# 1 0.06561407052931711
# Computing AP for class:  1
# 1 0.30553190140528436
# evaluating 7 scans...
# scans processed: 7
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.154          0.293          0.460
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.154          0.293          0.460
#
# Epoch 389: 100% 25/25 [02:19<00:00,  5.60s/it, loss=111, v_num=orgb]
#                                                           Checkpoint created
# Epoch 390: 100% 18/18 [01:29<00:00,  4.96s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 391: 100% 18/18 [01:31<00:00,  5.09s/it, loss=111, v_num=orgb]Checkpoint created
# Epoch 392: 100% 18/18 [01:34<00:00,  5.23s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 393: 100% 18/18 [01:33<00:00,  5.22s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 394: 100% 18/18 [01:29<00:00,  4.99s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 395: 100% 18/18 [01:28<00:00,  4.94s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 396: 100% 18/18 [01:30<00:00,  5.05s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 397: 100% 18/18 [01:32<00:00,  5.12s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 398: 100% 18/18 [01:31<00:00,  5.08s/it, loss=111, v_num=orgb]Checkpoint created
# Epoch 399:   0% 0/25 [00:00<?, ?it/s, loss=111, v_num=orgb]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 399:  80% 20/25 [01:35<00:23,  4.78s/it, loss=111, v_num=orgb]
# Epoch 399: 100% 25/25 [01:55<00:00,  4.63s/it, loss=111, v_num=orgb]Computing AP for class:  1
# 1 0.09340476290612168
# Computing AP for class:  1
# 1 0.2979130732521189
# evaluating 7 scans...
# scans processed: 7
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.164          0.278          0.449
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.164          0.278          0.449
#
# Epoch 399: 100% 25/25 [02:17<00:00,  5.48s/it, loss=110, v_num=orgb]
#                                                           Checkpoint created
# Epoch 400: 100% 18/18 [01:32<00:00,  5.12s/it, loss=112, v_num=orgb]Checkpoint created
# Epoch 401: 100% 18/18 [01:28<00:00,  4.92s/it, loss=111, v_num=orgb]Checkpoint created
# Epoch 402: 100% 18/18 [01:33<00:00,  5.17s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 403: 100% 18/18 [01:27<00:00,  4.88s/it, loss=113, v_num=orgb]Checkpoint created
# Epoch 404: 100% 18/18 [01:31<00:00,  5.06s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 405: 100% 18/18 [01:28<00:00,  4.91s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 406: 100% 18/18 [01:28<00:00,  4.90s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 407: 100% 18/18 [01:29<00:00,  4.98s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 408: 100% 18/18 [01:30<00:00,  5.02s/it, loss=107, v_num=orgb]Checkpoint created
# Epoch 409:   0% 0/25 [00:00<?, ?it/s, loss=107, v_num=orgb]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 409:  80% 20/25 [01:37<00:24,  4.87s/it, loss=107, v_num=orgb]
# Epoch 409: 100% 25/25 [01:57<00:00,  4.69s/it, loss=107, v_num=orgb]Computing AP for class:  1
# 1 0.10942138859794062
# Computing AP for class:  1
# 1 0.3304704434396702
# evaluating 7 scans...
# scans processed: 7
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.185          0.314          0.469
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.185          0.314          0.469
#
# Epoch 409: 100% 25/25 [02:19<00:00,  5.59s/it, loss=111, v_num=orgb]
#                                                           Checkpoint created
# Epoch 410: 100% 18/18 [01:35<00:00,  5.28s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 411: 100% 18/18 [01:29<00:00,  4.95s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 412: 100% 18/18 [01:34<00:00,  5.26s/it, loss=111, v_num=orgb]Checkpoint created
# Epoch 413: 100% 18/18 [01:31<00:00,  5.11s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 414: 100% 18/18 [01:35<00:00,  5.33s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 415: 100% 18/18 [01:30<00:00,  5.03s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 416: 100% 18/18 [01:30<00:00,  5.05s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 417: 100% 18/18 [01:32<00:00,  5.16s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 418: 100% 18/18 [01:37<00:00,  5.43s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 419:   0% 0/25 [00:00<?, ?it/s, loss=109, v_num=orgb]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 419:  80% 20/25 [01:35<00:23,  4.75s/it, loss=109, v_num=orgb]
# Epoch 419: 100% 25/25 [01:55<00:00,  4.61s/it, loss=109, v_num=orgb]Computing AP for class:  1
# 1 0.09364790031328296
# Computing AP for class:  1
# 1 0.3365752582734476
# evaluating 7 scans...
# scans processed: 7
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.195          0.316          0.453
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.195          0.316          0.453
#
# Epoch 419: 100% 25/25 [02:17<00:00,  5.52s/it, loss=111, v_num=orgb]
#                                                           Checkpoint created
# Epoch 420: 100% 18/18 [01:32<00:00,  5.16s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 421: 100% 18/18 [01:28<00:00,  4.94s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 422: 100% 18/18 [01:27<00:00,  4.85s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 423: 100% 18/18 [01:38<00:00,  5.47s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 424: 100% 18/18 [01:28<00:00,  4.91s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 425: 100% 18/18 [01:33<00:00,  5.22s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 426: 100% 18/18 [01:32<00:00,  5.14s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 427: 100% 18/18 [01:30<00:00,  5.02s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 428: 100% 18/18 [01:32<00:00,  5.15s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 429:   0% 0/25 [00:00<?, ?it/s, loss=110, v_num=orgb]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 429:  80% 20/25 [01:40<00:25,  5.04s/it, loss=110, v_num=orgb]
# Epoch 429: 100% 25/25 [02:01<00:00,  4.84s/it, loss=110, v_num=orgb]Computing AP for class:  1
# 1 0.08668893886043887
# Computing AP for class:  1
# 1 0.3073499354121795
# evaluating 7 scans...
# scans processed: 7
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.161          0.307          0.455
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.161          0.307          0.455
#
# Epoch 429: 100% 25/25 [02:23<00:00,  5.73s/it, loss=110, v_num=orgb]
#                                                           Checkpoint created
# Epoch 430: 100% 18/18 [01:36<00:00,  5.33s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 431: 100% 18/18 [01:33<00:00,  5.18s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 432: 100% 18/18 [01:33<00:00,  5.20s/it, loss=106, v_num=orgb]Checkpoint created
# Epoch 433: 100% 18/18 [01:35<00:00,  5.33s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 434: 100% 18/18 [01:32<00:00,  5.16s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 435: 100% 18/18 [01:30<00:00,  5.05s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 436: 100% 18/18 [01:34<00:00,  5.23s/it, loss=107, v_num=orgb]Checkpoint created
# Epoch 437: 100% 18/18 [01:32<00:00,  5.16s/it, loss=110, v_num=orgb]Checkpoint created
# Epoch 438: 100% 18/18 [01:32<00:00,  5.13s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 439:   0% 0/25 [00:00<?, ?it/s, loss=108, v_num=orgb]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 439:  80% 20/25 [01:43<00:25,  5.17s/it, loss=108, v_num=orgb]
# Epoch 439: 100% 25/25 [02:03<00:00,  4.96s/it, loss=108, v_num=orgb]Computing AP for class:  1
# 1 0.08755733403156833
# Computing AP for class:  1
# 1 0.32453997118650146
# evaluating 7 scans...
# scans processed: 7
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.186          0.327          0.463
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.186          0.327          0.463
#
# Epoch 439: 100% 25/25 [02:25<00:00,  5.81s/it, loss=109, v_num=orgb]
#                                                           Checkpoint created
# Epoch 440: 100% 18/18 [01:33<00:00,  5.21s/it, loss=107, v_num=orgb]Checkpoint created
# Epoch 441: 100% 18/18 [01:39<00:00,  5.54s/it, loss=107, v_num=orgb]Checkpoint created
# Epoch 442: 100% 18/18 [01:31<00:00,  5.06s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 443: 100% 18/18 [01:33<00:00,  5.17s/it, loss=107, v_num=orgb]Checkpoint created
# Epoch 444: 100% 18/18 [01:34<00:00,  5.25s/it, loss=106, v_num=orgb]Checkpoint created
# Epoch 445: 100% 18/18 [01:30<00:00,  5.00s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 446: 100% 18/18 [01:28<00:00,  4.94s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 447: 100% 18/18 [01:37<00:00,  5.41s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 448: 100% 18/18 [01:34<00:00,  5.26s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 449:   0% 0/25 [00:00<?, ?it/s, loss=109, v_num=orgb]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 449:  80% 20/25 [01:42<00:25,  5.11s/it, loss=109, v_num=orgb]
# Epoch 449: 100% 25/25 [02:03<00:00,  4.93s/it, loss=109, v_num=orgb]Computing AP for class:  1
# 1 0.1008439081862862
# Computing AP for class:  1
# 1 0.33307463169024354
# evaluating 7 scans...
# scans processed: 7
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.191          0.329          0.455
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.191          0.329          0.455
#
# Epoch 449: 100% 25/25 [02:25<00:00,  5.84s/it, loss=109, v_num=orgb]
#                                                           Checkpoint created
# Epoch 450: 100% 18/18 [01:40<00:00,  5.58s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 451: 100% 18/18 [01:35<00:00,  5.28s/it, loss=109, v_num=orgb]Checkpoint created
# Epoch 452: 100% 18/18 [01:34<00:00,  5.25s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch 453: 100% 18/18 [01:36<00:00,  5.35s/it, loss=107, v_num=orgb]Checkpoint created
# Epoch 454: 100% 18/18 [01:30<00:00,  5.01s/it, loss=107, v_num=orgb]Checkpoint created
# Epoch 455: 100% 18/18 [01:38<00:00,  5.48s/it, loss=108, v_num=orgb]Checkpoint created
# Epoch
# wandb:         val_loss_dice_3 ▃▅▅██▁▄▆▃▅▄▃
# wandb:         val_loss_dice_4 ▂▅▂█▆▁▄▆▃▄▄▃
# wandb:         val_loss_dice_5 ▂▇▂█▇▁▅▆▃▆▆▅
# wandb:         val_loss_dice_6 ▁▆▃█▇▁▅▇▃▆▆▅
# wandb:         val_loss_dice_7 ▁▇▃█▇▂▅▆▄▇▆▆
# wandb:         val_loss_dice_8 ▃▇▂█▇▁▆▆▃▆▅▄
# wandb:         val_loss_dice_9 ▃▆▃▇█▁▅▇▃▆▅▅
# wandb:           val_loss_mask ▂▄▁██▁▄▆▃▄▄▄
# wandb:         val_loss_mask_0 ▆▁▅█▇█▄▅▄▄▃▄
# wandb:         val_loss_mask_1 ▂█▄▅▆▁▄▃▃▃▃▃
# wandb:        val_loss_mask_10 ▁▅▂▆█▃▆▅▄▆▄▄
# wandb:        val_loss_mask_11 ▂▆▁▅█▂▆▇▅▆▆▅
# wandb:         val_loss_mask_2 ▁█▂█▇▃▅▆▅▅▅▄
# wandb:         val_loss_mask_3 ▁▆▃▇█▃▇▇▇▆▆▆
# wandb:         val_loss_mask_4 ▁▄▂█▆▂▆▆▅▅▅▅
# wandb:         val_loss_mask_5 ▁▇▁█▇▂▇▆▆▆▄▅
# wandb:         val_loss_mask_6 ▁▆▂█▇▃▇▇▆▇▅▆
# wandb:         val_loss_mask_7 ▁▆▂▇█▂▅▇▅█▆▅
# wandb:         val_loss_mask_8 ▁▇▂██▂▅▆▄▆▅▄
# wandb:         val_loss_mask_9 ▁█▁██▃█▇▆▇▆▅
# wandb:             val_mean_ap ▁▃▆▇▂▆▇▆█▆█▇
# wandb:          val_mean_ap_25 ▃▁▅▂▂▄▂▅█▇▇▄
# wandb:          val_mean_ap_50 ▃▁▅▅▄▆▇▆█▆█▇
# wandb:      val_mean_box_ap_25 ▂▁▅▅▂▄▅▇▇█▇▆
# wandb:      val_mean_box_ap_50 ▁▄▆▄▃▄▅▇▆█▆▆
# wandb:        val_mean_loss_ce ▁▄▄█▇▄▇█▆▇▇▆
# wandb:      val_mean_loss_dice ▂▆▃██▁▅▆▃▆▅▄
# wandb:      val_mean_loss_mask ▁▇▂██▂▆▆▅▆▅▅
# wandb:
# wandb: Run summary:
# wandb:                   epoch 499
# wandb:                lr-AdamW 0.0
# wandb:           train_loss_ce 0.29278
# wandb:         train_loss_ce_0 1.26128
# wandb:         train_loss_ce_1 0.46878
# wandb:        train_loss_ce_10 0.31569
# wandb:        train_loss_ce_11 0.32339
# wandb:         train_loss_ce_2 0.46061
# wandb:         train_loss_ce_3 0.4215
# wandb:         train_loss_ce_4 0.39823
# wandb:         train_loss_ce_5 0.37833
# wandb:         train_loss_ce_6 0.37292
# wandb:         train_loss_ce_7 0.34925
# wandb:         train_loss_ce_8 0.32644
# wandb:         train_loss_ce_9 0.31881
# wandb:         train_loss_dice 2.28956
# wandb:       train_loss_dice_0 7.73596
# wandb:       train_loss_dice_1 3.34518
# wandb:      train_loss_dice_10 2.33692
# wandb:      train_loss_dice_11 2.2551
# wandb:       train_loss_dice_2 2.90066
# wandb:       train_loss_dice_3 2.49086
# wandb:       train_loss_dice_4 2.27749
# wandb:       train_loss_dice_5 2.25112
# wandb:       train_loss_dice_6 2.31205
# wandb:       train_loss_dice_7 2.26368
# wandb:       train_loss_dice_8 2.24071
# wandb:       train_loss_dice_9 2.25621
# wandb:         train_loss_mask 0.46495
# wandb:       train_loss_mask_0 2.56649
# wandb:       train_loss_mask_1 0.70322
# wandb:      train_loss_mask_10 0.46092
# wandb:      train_loss_mask_11 0.44632
# wandb:       train_loss_mask_2 0.61181
# wandb:       train_loss_mask_3 0.49442
# wandb:       train_loss_mask_4 0.46679
# wandb:       train_loss_mask_5 0.47712
# wandb:       train_loss_mask_6 0.46502
# wandb:       train_loss_mask_7 0.46445
# wandb:       train_loss_mask_8 0.44721
# wandb:       train_loss_mask_9 0.45009
# wandb:         train_loss_mean 108.69133
# wandb:      train_mean_loss_ce 0.43754
# wandb:    train_mean_loss_dice 2.84273
# wandb:    train_mean_loss_mask 0.65529
# wandb:     trainer/global_step 8999
# wandb:        val_Other_val_ap 0.19153
# wandb:     val_Other_val_ap_25 0.46223
# wandb:     val_Other_val_ap_50 0.3286
# wandb: val_Trees_val_box_ap_25 0.34455
# wandb: val_Trees_val_box_ap_50 0.11149
# wandb:             val_loss_ce 1.27948
# wandb:           val_loss_ce_0 1.08261
# wandb:           val_loss_ce_1 0.80486
# wandb:          val_loss_ce_10 1.33856
# wandb:          val_loss_ce_11 1.29782
# wandb:           val_loss_ce_2 0.88545
# wandb:           val_loss_ce_3 0.95656
# wandb:           val_loss_ce_4 1.02624
# wandb:           val_loss_ce_5 1.13699
# wandb:           val_loss_ce_6 1.2316
# wandb:           val_loss_ce_7 1.23205
# wandb:           val_loss_ce_8 1.24031
# wandb:           val_loss_ce_9 1.28685
# wandb:           val_loss_dice 1.11689
# wandb:         val_loss_dice_0 1.96388
# wandb:         val_loss_dice_1 1.33327
# wandb:        val_loss_dice_10 1.14954
# wandb:        val_loss_dice_11 1.15332
# wandb:         val_loss_dice_2 1.27554
# wandb:         val_loss_dice_3 1.21805
# wandb:         val_loss_dice_4 1.16532
# wandb:         val_loss_dice_5 1.17578
# wandb:         val_loss_dice_6 1.18056
# wandb:         val_loss_dice_7 1.17469
# wandb:         val_loss_dice_8 1.13544
# wandb:         val_loss_dice_9 1.13967
# wandb:           val_loss_mask 0.21908
# wandb:         val_loss_mask_0 0.40763
# wandb:         val_loss_mask_1 0.28162
# wandb:        val_loss_mask_10 0.23359
# wandb:        val_loss_mask_11 0.23208
# wandb:         val_loss_mask_2 0.28071
# wandb:         val_loss_mask_3 0.25773
# wandb:         val_loss_mask_4 0.24275
# wandb:         val_loss_mask_5 0.24592
# wandb:         val_loss_mask_6 0.25206
# wandb:         val_loss_mask_7 0.23412
# wandb:         val_loss_mask_8 0.2145
# wandb:         val_loss_mask_9 0.22918
# wandb:             val_mean_ap 0.19153
# wandb:          val_mean_ap_25 0.46223
# wandb:          val_mean_ap_50 0.3286
# wandb:      val_mean_box_ap_25 0.34455
# wandb:      val_mean_box_ap_50 0.11149
# wandb:        val_mean_loss_ce 1.13841
# wandb:      val_mean_loss_dice 1.24477
# wandb:      val_mean_loss_mask 0.25623
# wandb:
# wandb: Synced all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb: https://wandb.ai/ram212/las/runs/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb
# wandb: Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /content/drive/MyDrive/MRes/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb/wandb/run-20230627_123244-all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb/logs

# %% [markdown]
# # Mask3D inference and saving visualizations

# %%
# testing visualization data split
# this puts the testing files into the validation folder -- this is necessary
# because the Mask3D test script does not work as intended

import random
import pandas as pd
import shutil

data_location = "/content/Mask3D/data/FORinstance_dataset/"
train_location = "/content/Mask3D/data/las/train/"
validation_location = "/content/Mask3D/data/las/validation/"
test_location = "/content/Mask3D/data/las/test/"

data_split_metadata = pd.read_csv(data_location + "data_split_metadata.csv")
data_split_metadata = data_split_metadata[data_split_metadata["folder"] == "NIBIO2"]

train_count = 0
for path in data_split_metadata["path"]:
    if data_split_metadata.loc[data_split_metadata["path"] == path]["split"].item() == "train":
        shutil.copyfile(data_location + path, train_location + path.replace("NIBIO2/", ""))
    else:
        shutil.copyfile(data_location + path, validation_location + path.replace("NIBIO2/", ""))

train_files = os.listdir(train_location)

validation_plots = ["plot59_annotated.las", "plot26_annotated.las",
                    "plot21_annotated.las", "plot8_annotated.las",
                    "plot20_annotated.las", "plot57_annotated.las",
                    "plot12_annotated.las"]

for train_file in train_files:
    if train_file in validation_plots:
        os.remove(train_location + train_file)

# %%
# make sure you run the code from within the Mask3D directory
# %cd /content/Mask3D/

# %%
# run the preprocessing script on the .las files

# !python -m datasets.preprocessing.las_preprocessing preprocess \
--data_dir="/content/Mask3D/data/las" \
--save_dir="/content/Mask3D/data/processed/las" \
--sample_proportion=1 \
--use_rgb=True \
--subplot_size=500.0

# %%
# log in to weights and biases to track experiment -- not required
# !wandb login

# %% [markdown]
# This is the script for producing the testing metrics, and also for getting the files for visualizing the predicted masks.

# %%
# %%shell
# export OMP_NUM_THREADS=3
#
# CURR_DBSCAN=14.0
# CURR_TOPK=10
# CURR_QUERY=160
# CURR_SIZE=250
#
# EXPERIMENT_NAME="all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb"
# SAVE_DIRECTORY="/content/saved/"
#
# # VIZ TEST
# python main_instance_segmentation.py \
# general.experiment_name=${EXPERIMENT_NAME} \
# general.project_name="las" \
# data/datasets=las \
# general.num_targets=2 \
# data.num_labels=2 \
# data.voxel_size=6.0 \
# data.num_workers=0 \
# data.cache_data=true \
# data.cropping_v1=false \
# data.cropping=false \
# data.batch_size=1 \
# data.test_batch_size=1 \
# general.reps_per_epoch=5 \
# model.num_queries=${CURR_QUERY} \
# general.use_dbscan=false \
# general.on_crops=true \
# model.config.backbone._target_=models.Res16UNet18B \
# data.crop_length=${CURR_SIZE} \
# data.subplot_size=500.0 \
# general.eval_inner_core=-1 \
# general.save_visualizations=true \
# general.save_dir="${SAVE_DIRECTORY}${EXPERIMENT_NAME}" \
# general.checkpoint="/content/drive/MyDrive/MRes/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb/last-epoch.ckpt" \
# trainer.check_val_every_n_epoch=1 \
# optimizer.lr=0.0000000000000001 \
# trainer.max_epochs=1
# Out:
# 2023-06-27 16:03:24.665493: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/seed.py:55: UserWarning: No seed found, seed set to 288011894
#   rank_zero_warn(f"No seed found, seed set to {seed}")
# Global seed set to 288011894
# {'_target_': 'pytorch_lightning.loggers.WandbLogger', 'project': '${general.project_name}', 'name': '${general.experiment_name}', 'save_dir': '${general.save_dir}', 'entity': 'ram212', 'resume': 'allow', 'id': '${general.experiment_name}'}
# wandb: Currently logged in as: ram212. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.2
# wandb: Run data is saved locally in /content/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb/wandb/run-20230627_160328-all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Resuming run all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb
# wandb: ⭐️ View project at https://wandb.ai/ram212/las
# wandb: 🚀 View run at https://wandb.ai/ram212/las/runs/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb
# [2023-06-27 16:03:35,381][__main__][INFO] - {'general_train_mode': True, 'general_task': 'instance_segmentation', 'general_seed': None, 'general_checkpoint': '/content/drive/MyDrive/MRes/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_norgb/last-epoch.ckpt', 'general_backbone_checkpoint': None, 'general_freeze_backbone': False, 'general_linear_probing_backbone': False, 'general_train_on_segments': False, 'general_eval_on_segments': False, 'general_filter_out_instances': False, 'general_save_visualizations': True, 'general_visualization_point_size': 20, 'general_decoder_id': -1, 'general_export': False, 'general_use_dbscan': False, 'general_ignore_class_threshold': 100, 'general_project_name': 'las', 'general_workspace': 'jonasschult', 'general_experiment_name': 'all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb', 'general_num_targets': 2, 'general_add_instance': True, 'general_dbscan_eps': 0.95, 'general_dbscan_min_points': 1, 'general_export_threshold': 0.0001, 'general_reps_per_epoch': 5, 'general_on_crops': True, 'general_scores_threshold': 0.0, 'general_iou_threshold': 1.0, 'general_area': 5, 'general_eval_inner_core': -1, 'general_topk_per_image': 100, 'general_ignore_mask_idx': [], 'general_max_batch_size': 99999999, 'general_save_dir': '/content/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb', 'general_gpus': 1, 'data_train_mode': 'train', 'data_validation_mode': 'validation', 'data_test_mode': 'validation', 'data_ignore_label': 255, 'data_add_raw_coordinates': True, 'data_add_colors': True, 'data_add_normals': False, 'data_in_channels': 3, 'data_num_labels': 2, 'data_add_instance': True, 'data_task': 'instance_segmentation', 'data_pin_memory': False, 'data_num_workers': 0, 'data_batch_size': 1, 'data_test_batch_size': 1, 'data_cache_data': True, 'data_voxel_size': 6.0, 'data_reps_per_epoch': 5, 'data_cropping': False, 'data_cropping_args_min_points': 30000, 'data_cropping_args_aspect': 0.8, 'data_cropping_args_min_crop': 0.5, 'data_cropping_args_max_crop': 1.0, 'data_crop_min_size': 20000, 'data_crop_length': 250, 'data_subplot_size': 500.0, 'data_cropping_v1': False, 'data_train_dataloader__target_': 'torch.utils.data.DataLoader', 'data_train_dataloader_shuffle': True, 'data_train_dataloader_pin_memory': False, 'data_train_dataloader_num_workers': 0, 'data_train_dataloader_batch_size': 1, 'data_validation_dataloader__target_': 'torch.utils.data.DataLoader', 'data_validation_dataloader_shuffle': False, 'data_validation_dataloader_pin_memory': False, 'data_validation_dataloader_num_workers': 1, 'data_validation_dataloader_batch_size': 1, 'data_test_dataloader__target_': 'torch.utils.data.DataLoader', 'data_test_dataloader_shuffle': False, 'data_test_dataloader_pin_memory': False, 'data_test_dataloader_num_workers': 1, 'data_test_dataloader_batch_size': 1, 'data_train_dataset__target_': 'datasets.semseg.SemanticSegmentationDataset', 'data_train_dataset_dataset_name': 'las', 'data_train_dataset_data_dir': 'data/processed/las', 'data_train_dataset_image_augmentations_path': 'conf/augmentation/albumentations_aug.yaml', 'data_train_dataset_volume_augmentations_path': 'conf/augmentation/volumentations_aug.yaml', 'data_train_dataset_label_db_filepath': 'data/processed/las/label_database.yaml', 'data_train_dataset_color_mean_std': 'data/processed/las/color_mean_std.yaml', 'data_train_dataset_data_percent': 1.0, 'data_train_dataset_mode': 'train', 'data_train_dataset_ignore_label': 255, 'data_train_dataset_num_labels': 2, 'data_train_dataset_add_raw_coordinates': True, 'data_train_dataset_add_colors': True, 'data_train_dataset_add_normals': False, 'data_train_dataset_add_instance': True, 'data_train_dataset_cache_data': True, 'data_train_dataset_instance_oversampling': 0.0, 'data_train_dataset_place_around_existing': False, 'data_train_dataset_point_per_cut': 0, 'data_train_dataset_max_cut_region': 0, 'data_train_dataset_flip_in_center':  ...
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:446: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:57: LightningDeprecationWarning: Setting `Trainer(weights_save_path=)` has been deprecated in v1.6 and will be removed in v1.8. Please pass ``dirpath`` directly to the `ModelCheckpoint` callback
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /content/Mask3D/datasets/semseg.py:594: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(f)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:616: UserWarning: Checkpoint directory /content/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type         | Params
# -------------------------------------------
# 0 | model     | Mask3D       | 19.0 M
# 1 | criterion | SetCriterion | 0
# -------------------------------------------
# 19.0 M    Trainable params
# 0         Non-trainable params
# 19.0 M    Total params
# 75.810    Total estimated model params size (MB)
# Sanity Checking DataLoader 0: 100% 2/2 [00:21<00:00, 10.57s/it]Computing AP for class:  1
# 1 0.004812056395152335
# Computing AP for class:  1
# 1 0.04139347363506584
# evaluating 2 scans...
# scans processed: 2
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.041          0.087          0.253
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.041          0.087          0.253
#
# Epoch 0:  90% 140/155 [02:24<00:15,  1.03s/it, loss=22.6, v_num=orgb]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/15 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/15 [00:00<?, ?it/s]
# Epoch 0: 100% 155/155 [05:05<00:00,  1.97s/it, loss=22.6, v_num=orgb]Computing AP for class:  1
# 1 0.005825541184442856
# Computing AP for class:  1
# 1 0.06284516504120459
# evaluating 15 scans...
# scans processed: 15
#
# ################################################################
# what           :             AP         AP_50%         AP_25%
# ################################################################
# Other          :          0.068          0.139          0.356
# Trees          :            nan            nan            nan
# ----------------------------------------------------------------
# average        :          0.068          0.139          0.356
#
# Epoch 0: 100% 155/155 [05:43<00:00,  2.22s/it, loss=22.6, v_num=orgb]
#                                                             Checkpoint created
# Epoch 0: 100% 155/155 [05:45<00:00,  2.23s/it, loss=22.6, v_num=orgb]`Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100% 155/155 [05:53<00:00,  2.28s/it, loss=22.6, v_num=orgb]
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb:                   epoch ▁▁▁▁
# wandb:                lr-AdamW █▁
# wandb:           train_loss_ce █▁
# wandb:         train_loss_ce_0 ▁█
# wandb:         train_loss_ce_1 █▁
# wandb:        train_loss_ce_10 █▁
# wandb:        train_loss_ce_11 █▁
# wandb:         train_loss_ce_2 █▁
# wandb:         train_loss_ce_3 █▁
# wandb:         train_loss_ce_4 █▁
# wandb:         train_loss_ce_5 █▁
# wandb:         train_loss_ce_6 █▁
# wandb:         train_loss_ce_7 █▁
# wandb:         train_loss_ce_8 █▁
# wandb:         train_loss_ce_9 █▁
# wandb:         train_loss_dice █▁
# wandb:       train_loss_dice_0 █▁
# wandb:       train_loss_dice_1 █▁
# wandb:      train_loss_dice_10 █▁
# wandb:      train_loss_dice_11 █▁
# wandb:       train_loss_dice_2 █▁
# wandb:       train_loss_dice_3 █▁
# wandb:       train_loss_dice_4 █▁
# wandb:       train_loss_dice_5 █▁
# wandb:       train_loss_dice_6 █▁
# wandb:       train_loss_dice_7 █▁
# wandb:       train_loss_dice_8 █▁
# wandb:       train_loss_dice_9 █▁
# wandb:         train_loss_mask █▁
# wandb:       train_loss_mask_0 ▁█
# wandb:       train_loss_mask_1 ▁█
# wandb:      train_loss_mask_10 ▁█
# wandb:      train_loss_mask_11 ▁█
# wandb:       train_loss_mask_2 █▁
# wandb:       train_loss_mask_3 █▁
# wandb:       train_loss_mask_4 ▁█
# wandb:       train_loss_mask_5 ▁█
# wandb:       train_loss_mask_6 ▁█
# wandb:       train_loss_mask_7 ▁█
# wandb:       train_loss_mask_8 █▁
# wandb:       train_loss_mask_9 █▁
# wandb:         train_loss_mean ▁
# wandb:      train_mean_loss_ce █▁
# wandb:    train_mean_loss_dice █▁
# wandb:    train_mean_loss_mask ▁█
# wandb:     trainer/global_step ▁▁▅▅██
# wandb:        val_Other_val_ap ▁
# wandb:     val_Other_val_ap_25 ▁
# wandb:     val_Other_val_ap_50 ▁
# wandb: val_Trees_val_box_ap_25 ▁
# wandb: val_Trees_val_box_ap_50 ▁
# wandb:             val_loss_ce ▁
# wandb:           val_loss_ce_0 ▁
# wandb:           val_loss_ce_1 ▁
# wandb:          val_loss_ce_10 ▁
# wandb:          val_loss_ce_11 ▁
# wandb:           val_loss_ce_2 ▁
# wandb:           val_loss_ce_3 ▁
# wandb:           val_loss_ce_4 ▁
# wandb:           val_loss_ce_5 ▁
# wandb:           val_loss_ce_6 ▁
# wandb:           val_loss_ce_7 ▁
# wandb:           val_loss_ce_8 ▁
# wandb:           val_loss_ce_9 ▁
# wandb:           val_loss_dice ▁
# wandb:         val_loss_dice_0 ▁
# wandb:         val_loss_dice_1 ▁
# wandb:        val_loss_dice_10 ▁
# wandb:        val_loss_dice_11 ▁
# wandb:         val_loss_dice_2 ▁
# wandb:         val_loss_dice_3 ▁
# wandb:         val_loss_dice_4 ▁
# wandb:         val_loss_dice_5 ▁
# wandb:         val_loss_dice_6 ▁
# wandb:         val_loss_dice_7 ▁
# wandb:         val_loss_dice_8 ▁
# wandb:         val_loss_dice_9 ▁
# wandb:           val_loss_mask ▁
# wandb:         val_loss_mask_0 ▁
# wandb:         val_loss_mask_1 ▁
# wandb:        val_loss_mask_10 ▁
# wandb:        val_loss_mask_11 ▁
# wandb:         val_loss_mask_2 ▁
# wandb:         val_loss_mask_3 ▁
# wandb:         val_loss_mask_4 ▁
# wandb:         val_loss_mask_5 ▁
# wandb:         val_loss_mask_6 ▁
# wandb:         val_loss_mask_7 ▁
# wandb:         val_loss_mask_8 ▁
# wandb:         val_loss_mask_9 ▁
# wandb:             val_mean_ap ▁
# wandb:          val_mean_ap_25 ▁
# wandb:          val_mean_ap_50 ▁
# wandb:      val_mean_box_ap_25 ▁
# wandb:      val_mean_box_ap_50 ▁
# wandb:        val_mean_loss_ce ▁
# wandb:      val_mean_loss_dice ▁
# wandb:      val_mean_loss_mask ▁
# wandb:
# wandb: Run summary:
# wandb:                   epoch 0
# wandb:                lr-AdamW 0.0
# wandb:           train_loss_ce 0.1739
# wandb:         train_loss_ce_0 1.14949
# wandb:         train_loss_ce_1 0.30959
# wandb:        train_loss_ce_10 0.17755
# wandb:        train_loss_ce_11 0.17424
# wandb:         train_loss_ce_2 0.22738
# wandb:         train_loss_ce_3 0.20728
# wandb:         train_loss_ce_4 0.27415
# wandb:         train_loss_ce_5 0.30638
# wandb:         train_loss_ce_6 0.29816
# wandb:         train_loss_ce_7 0.2697
# wandb:         train_loss_ce_8 0.23678
# wandb:         train_loss_ce_9 0.1892
# wandb:         train_loss_dice 0.8723
# wandb:       train_loss_dice_0 1.95612
# wandb:       train_loss_dice_1 1.11754
# wandb:      train_loss_dice_10 0.92025
# wandb:      train_loss_dice_11 0.90726
# wandb:       train_loss_dice_2 1.06893
# wandb:       train_loss_dice_3 1.00581
# wandb:       train_loss_dice_4 0.90566
# wandb:       train_loss_dice_5 0.88794
# wandb:       train_loss_dice_6 0.90862
# wandb:       train_loss_dice_7 0.90437
# wandb:       train_loss_dice_8 0.87745
# wandb:       train_loss_dice_9 0.90602
# wandb:         train_loss_mask 0.14376
# wandb:       train_loss_mask_0 0.52028
# wandb:       train_loss_mask_1 0.2209
# wandb:      train_loss_mask_10 0.16283
# wandb:      train_loss_mask_11 0.16672
# wandb:       train_loss_mask_2 0.20095
# wandb:       train_loss_mask_3 0.17362
# wandb:       train_loss_mask_4 0.16419
# wandb:       train_loss_mask_5 0.16389
# wandb:       train_loss_mask_6 0.16859
# wandb:       train_loss_mask_7 0.17048
# wandb:       train_loss_mask_8 0.15257
# wandb:       train_loss_mask_9 0.15864
# wandb:         train_loss_mean 22.80987
# wandb:      train_mean_loss_ce 0.30722
# wandb:    train_mean_loss_dice 1.01833
# wandb:    train_mean_loss_mask 0.19749
# wandb:     trainer/global_step 139
# wandb:        val_Other_val_ap 0.06783
# wandb:     val_Other_val_ap_25 0.35628
# wandb:     val_Other_val_ap_50 0.13919
# wandb: val_Trees_val_box_ap_25 0.06285
# wandb: val_Trees_val_box_ap_50 0.00583
# wandb:             val_loss_ce 0.86435
# wandb:           val_loss_ce_0 1.11414
# wandb:           val_loss_ce_1 0.45724
# wandb:          val_loss_ce_10 0.83312
# wandb:          val_loss_ce_11 0.94607
# wandb:           val_loss_ce_2 0.47973
# wandb:           val_loss_ce_3 0.48179
# wandb:           val_loss_ce_4 0.54241
# wandb:           val_loss_ce_5 0.74233
# wandb:           val_loss_ce_6 0.75394
# wandb:           val_loss_ce_7 0.82885
# wandb:           val_loss_ce_8 0.82444
# wandb:           val_loss_ce_9 0.87789
# wandb:           val_loss_dice 1.28011
# wandb:         val_loss_dice_0 1.95482
# wandb:         val_loss_dice_1 1.44115
# wandb:        val_loss_dice_10 1.29221
# wandb:        val_loss_dice_11 1.2878
# wandb:         val_loss_dice_2 1.40145
# wandb:         val_loss_dice_3 1.35318
# wandb:         val_loss_dice_4 1.31195
# wandb:         val_loss_dice_5 1.30663
# wandb:         val_loss_dice_6 1.30874
# wandb:         val_loss_dice_7 1.30286
# wandb:         val_loss_dice_8 1.28632
# wandb:         val_loss_dice_9 1.29072
# wandb:           val_loss_mask 0.46663
# wandb:         val_loss_mask_0 0.45859
# wandb:         val_loss_mask_1 0.5316
# wandb:        val_loss_mask_10 0.4946
# wandb:        val_loss_mask_11 0.49029
# wandb:         val_loss_mask_2 0.51105
# wandb:         val_loss_mask_3 0.47977
# wandb:         val_loss_mask_4 0.45119
# wandb:         val_loss_mask_5 0.46809
# wandb:         val_loss_mask_6 0.48658
# wandb:         val_loss_mask_7 0.48601
# wandb:         val_loss_mask_8 0.46126
# wandb:         val_loss_mask_9 0.48367
# wandb:             val_mean_ap 0.06783
# wandb:          val_mean_ap_25 0.35628
# wandb:          val_mean_ap_50 0.13919
# wandb:      val_mean_box_ap_25 0.06285
# wandb:      val_mean_box_ap_50 0.00583
# wandb:        val_mean_loss_ce 0.74972
# wandb:      val_mean_loss_dice 1.37061
# wandb:      val_mean_loss_mask 0.48226
# wandb:
# wandb: Synced all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb: https://wandb.ai/ram212/las/runs/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb
# wandb: Synced 3 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: /content/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb/wandb/run-20230627_160328-all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb/logs

# %%
# !zip -r /content/test_files_processed.zip /content/Mask3D/data/processed/las/validation
# Out:
#   adding: content/Mask3D/data/processed/las/validation/ (stored 0%)
#   adding: content/Mask3D/data/processed/las/validation/plot52_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot53_annotated_0.npy (deflated 80%)
#   adding: content/Mask3D/data/processed/las/validation/plot58_annotated_0.npy (deflated 79%)
#   adding: content/Mask3D/data/processed/las/validation/plot27_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot10_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot6_annotated.npy (deflated 85%)
#   adding: content/Mask3D/data/processed/las/validation/plot15_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot27_annotated_0.npy (deflated 79%)
#   adding: content/Mask3D/data/processed/las/validation/plot60_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot34_annotated.npy (deflated 85%)
#   adding: content/Mask3D/data/processed/las/validation/plot15_annotated_0.npy (deflated 79%)
#   adding: content/Mask3D/data/processed/las/validation/plot58_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot48_annotated_0.npy (deflated 81%)
#   adding: content/Mask3D/data/processed/las/validation/plot60_annotated_0.npy (deflated 79%)
#   adding: content/Mask3D/data/processed/las/validation/plot3_annotated_0.npy (deflated 79%)
#   adding: content/Mask3D/data/processed/las/validation/plot1_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot1_annotated_0.npy (deflated 79%)
#   adding: content/Mask3D/data/processed/las/validation/plot53_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot49_annotated.npy (deflated 85%)
#   adding: content/Mask3D/data/processed/las/validation/plot32_annotated_0.npy (deflated 80%)
#   adding: content/Mask3D/data/processed/las/validation/plot35_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot3_annotated.npy (deflated 84%)
#   adding: content/Mask3D/data/processed/las/validation/plot6_annotated_0.npy (deflated 80%)
#   adding: content/Mask3D/data/processed/las/validation/plot32_annotated.npy (deflated 85%)
#   adding: content/Mask3D/data/processed/las/validation/plot48_annotated.npy (deflated 85%)
#   adding: content/Mask3D/data/processed/las/validation/plot52_annotated_0.npy (deflated 79%)
#   adding: content/Mask3D/data/processed/las/validation/plot10_annotated_0.npy (deflated 79%)
#   adding: content/Mask3D/data/processed/las/validation/plot49_annotated_0.npy (deflated 80%)
#   adding: content/Mask3D/data/processed/las/validation/plot34_annotated_0.npy (deflated 80%)
#   adding: content/Mask3D/data/processed/las/validation/plot35_annotated_0.npy (deflated 79%)

# %%
# !zip -r /content/test_viz_norgb.zip /content/saved/all_plots_8.0_voxel_newotherclass_8batch_500crop_8batch_500epoch_viz_test_norgb/visualiz